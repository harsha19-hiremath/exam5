# %%
import pandas as pd
df=pd.read_csv('CSV.CSV')
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
df.drop('name',axis=1,inplace=True)
print(df.columns)
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['origin']=le.fit_transform(df['origin'])
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin
# 0            70       2
# 1            70       2
# 2            70       2
# 3            70       2
# ...

# %%
print(df['origin'].unique())
# Out:
# [2 1 0]

# %%
df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# dtype: int64

# %%
df.fillna(method='ffill',inplace=True)
df.isnull().sum()
# Out:
# C:\Users\Harsha\AppData\Local\Temp\ipykernel_10276\627222060.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill',inplace=True)
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model_year      0
# origin          0
# dtype: int64

# %%
x=df.iloc[ : ,1:8]
y=df[['mpg']]
x
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 0            8         307.0       130.0    3504          12.0          70
# 1            8         350.0       165.0    3693          11.5          70
# 2            8         318.0       150.0    3436          11.0          70
# 3            8         304.0       150.0    3433          12.0          70
# 4            8         302.0       140.0    3449          10.5          70
# ..         ...           ...         ...     ...           ...         ...
# 393          4         140.0        86.0    2790          15.6          82
# 394          4          97.0        52.0    2130          24.6          82
# 395          4         135.0        84.0    2295          11.6          82
# 396          4         120.0        79.0    2625          18.6          82
# 397          4         119.0        82.0    2720          19.4          82
#
#      origin
# 0         2
# 1         2
# 2         2
# 3         2
# ...

# %%
y
# Out:
#       mpg
# 0    18.0
# 1    15.0
# 2    18.0
# 3    16.0
# 4    17.0
# ..    ...
# 393  27.0
# 394  44.0
# 395  32.0
# 396  28.0
# 397  31.0
#
# [398 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
print("Training set size:",x_train.shape[0])
print("Testing set size:",x_test.shape[0])
# Out:
# Training set size: 318
# Testing set size: 80

# %%
x_train
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 372          4         151.0        90.0    2735          18.0          82
# 30           4         140.0        90.0    2264          15.5          71
# 171          4         134.0        96.0    2702          13.5          75
# 217          4         111.0        80.0    2155          14.8          77
# 303          4          85.0        65.0    2020          19.2          79
# ..         ...           ...         ...     ...           ...         ...
# 99           6         232.0       100.0    2945          16.0          73
# 131          4          71.0        65.0    1836          21.0          74
# 324          4          85.0        65.0    2110          19.2          80
# 167          4          97.0        75.0    2171          16.0          75
# 125          6         198.0        95.0    3102          16.5          74
#
#      origin
# 372       2
# 30        2
# 171       1
# 217       2
# ...

# %%
x_test
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 128          6         250.0       100.0    3336          17.0          74
# 248          4          91.0        60.0    1800          16.4          78
# 262          8         305.0       145.0    3425          13.2          78
# 396          4         120.0        79.0    2625          18.6          82
# 196          4          98.0        60.0    2164          22.1          76
# ..         ...           ...         ...     ...           ...         ...
# 338          4         135.0        84.0    2490          15.7          81
# 172          4          90.0        71.0    2223          16.5          75
# 374          4         151.0        92.0    3035          20.5          82
# 161          6         250.0       105.0    3897          18.5          75
# 24           6         199.0        90.0    2648          15.0          70
#
#      origin
# 128       2
# 248       1
# 262       2
# 396       2
# ...

# %%
y_train
# Out:
#       mpg
# 372  27.0
# 30   28.0
# 171  24.0
# 217  30.0
# 303  31.8
# ..    ...
# 99   18.0
# 131  32.0
# 324  40.8
# 167  29.0
# 125  20.0
#
# [318 rows x 1 columns]

# %%
y_test
# Out:
#       mpg
# 128  15.0
# 248  36.1
# 262  19.2
# 396  28.0
# 196  24.5
# ..    ...
# 338  27.2
# 172  25.0
# 374  23.0
# 161  16.0
# 24   21.0
#
# [80 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)
print("predicted MPG values:")
print(y_pred)
# Out:
# predicted MPG values:
# [[20.2021975 ]
#  [32.81940779]
#  [21.48983175]
#  [29.42205778]
#  [28.4317655 ]
#  [28.56196722]
#  [25.64670688]
#  [29.67447143]
#  [16.32301658]
#  [23.91573302]
#  [12.81622898]
#  [23.43005914]
#  [15.71712108]
#  [20.01278406]
#  [22.59558272]
#  [28.71253826]
#  [21.66853653]
#  [ 6.25409485]
#  [27.93185369]
#  [32.96394528]
#  [28.93148802]
#  [18.07037443]
#  [29.02346945]
#  [33.43870363]
#  [15.53785776]
#  [31.2041928 ]
#  [29.60441077]
#  [20.7043581 ]
#  [18.47398046]
#  [33.46070614]
#  [21.06033081]
#  [28.15487675]
#  [12.4358066 ]
#  [29.79009925]
#  [11.87632894]
#  [21.74888214]
#  [25.38627996]
#  [21.03395998]
#  [17.44707682]
#  [13.15157367]
#  [30.86519206]
#  [27.70239372]
#  [36.50856461]
#  [28.98095372]
#  [19.77034698]
#  [26.73281204]
#  [17.40572105]
#  [34.29606161]
#  [24.61583406]
#  [28.42237663]
#  [27.51694724]
#  [15.76662845]
#  [24.38408518]
#  [12.33289655]
#  [25.40605405]
#  [24.323474  ]
#  [30.72595383]
# ...

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
mse=mean_squared_error(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)
print("Mean Squared Error:",mse)
print("Mean Absolute Error:",mae)
print("R_Squared Scored Score:",r2)
# Out:
# Mean Squared Error: 11.254580560398916
# Mean Absolute Error: 2.6044986638029672
# R_Squared Scored Score: 0.821417588438299

# %%
import numpy as np
rmse=np.sqrt(mse)
print(rmse)
# Out:
# 3.3547847263869133

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
plt.scatter(x['cylinders'],y)
plt.title("cylinders vs MPG")
plt.xlabel("cylinders")
plt.ylabel("MPG")
plt.grid(True)
plt.show()

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
import re
import string

# %%
df= pd.read_csv("../input/fake-news-detection/Fake.csv")
df= pd.read_csv("../input/fake-news-detection/True.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df= pd.read_csv("../input/fake-news-detection/Fake.csv")
#       2 df= pd.read_csv("../input/fake-news-detection/True.csv")
#
# ...
